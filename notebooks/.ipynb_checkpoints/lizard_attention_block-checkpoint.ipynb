# %%
import sys
from pathlib import Path

project_root = Path.cwd().parents[0]
sys.path.append(str(project_root))

# %%
from modules.lizard import create_lizard_attention_config

# %%
import torch

# %%
cfg = create_lizard_attention_config(
    batch_size=2,
    seq_len=8192 * 4,
    hidden_size=256,
    num_heads=4,
    dtype="float32",
    device="cuda" if torch.cuda.is_available() else "cpu",
)

# %%
from modules.lizard_attention_block_pytorch import LizardAttentionBlock

# %%
torch_dtype = cfg.dtype.to_torch()
head_dim = cfg.hidden_size // cfg.num_heads

print(f"Configuring model with: {cfg}")
print(f"Head Dimension: {head_dim}")

model = (
    LizardAttentionBlock(
        d_model=cfg.hidden_size, n_heads=cfg.num_heads, window_size=32, alpha=0.5, m=4
    )
    .to(cfg.device)
    .to(torch_dtype)
)

q = torch.randn(
    cfg.batch_size,
    cfg.num_heads,
    cfg.seq_len,
    head_dim,
    device=cfg.device,
    dtype=torch_dtype,
)
k = torch.randn(
    cfg.batch_size,
    cfg.num_heads,
    cfg.seq_len,
    head_dim,
    device=cfg.device,
    dtype=torch_dtype,
)
v = torch.randn(
    cfg.batch_size,
    cfg.num_heads,
    cfg.seq_len,
    head_dim,
    device=cfg.device,
    dtype=torch_dtype,
)

output = model(q, k, v)

print(f"Input shape:  {q.shape}")
print(f"Output shape: {output.shape}")

assert q.shape == output.shape
# Out:
# Configuring model with: LizardAttentionBlockConfig(batch_size=2, seq_len=32768, hidden_size=256, num_heads=4, dtype=DTypeConfig(name='float32'), device='cuda')
# Head Dimension: 64
# Input shape:  torch.Size([2, 4, 32768, 64])
# Output shape: torch.Size([2, 4, 32768, 64])

# %%
def benchmark():
    model(q, k, v)

benchmark()

# %%
# %timeit -r 5 -n 100 benchmark()
# Out:
# 98.5 ms ± 455 μs per loop (mean ± std. dev. of 5 runs, 100 loops each)

# %%
import torch
import triton
from modules.lizard_attention_block_pytorch import LizardAttentionBlock

device = "cuda"
L = 32768  # 32k
D = 64     # Head Dim
H = 4      # Num Heads

model = LizardAttentionBlock(d_model=D*H, n_heads=H).to(device)
q = torch.randn(1, H, L, D, device=device, dtype=torch.float16)
k = torch.randn(1, H, L, D, device=device, dtype=torch.float16)
v = torch.randn(1, H, L, D, device=device, dtype=torch.float16)

print(f"Benchmarking L={L}...")

for _ in range(10):
    _ = model(q, k, v)
torch.cuda.synchronize()

starter, ender = torch.cuda.Event(enable_timing=True), torch.cuda.Event(enable_timing=True)
timings = []

for _ in range(100):
    starter.record()
    _ = model(q, k, v)
    ender.record()
    torch.cuda.synchronize()
    timings.append(starter.elapsed_time(ender))

import numpy as np
print(f"Latency: {np.mean(timings):.3f} ms ± {np.std(timings):.3f}")
print(f"Throughput: {1000/np.mean(timings):.1f} batches/sec")
# Out:
# Benchmarking L=32768...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 18
#      15 print(f"Benchmarking L={L}...")
#      17 for _ in range(10):
# ---> 18     _ = model(q, k, v)
#      19 torch.cuda.synchronize()
#      21 starter, ender = torch.cuda.Event(enable_timing=True), torch.cuda.Event(enable_timing=True)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
# ...
