# %%
import sys
from pathlib import Path

project_root = Path.cwd().parents[0]
sys.path.append(str(project_root))

# %%
from modules.gla.gla_block import GatedLinearAttention

# %%
import torch

# %%
model = GatedLinearAttention(d_model=128, num_heads=8, computation_dtype=torch.float32)
model = model.cuda()

x = torch.randn(2, 4096, 128, device='cuda', dtype=torch.float32)

print("Warming up GPU...")
for _ in range(10):
    _ = model(x)
torch.cuda.synchronize()

start_event = torch.cuda.Event(enable_timing=True)
end_event = torch.cuda.Event(enable_timing=True)

start_event.record()

n_loops = 100
for _ in range(n_loops):
    y = model(x)

end_event.record()
torch.cuda.synchronize()

elapsed_time_ms = start_event.elapsed_time(end_event)
avg_time = elapsed_time_ms / n_loops

print(f"Output shape: {y.shape}")
print(f"Total time for {n_loops} runs: {elapsed_time_ms:.2f} ms")
print(f"Average time per forward pass: {avg_time:.4f} ms")
# Out:
# Warming up GPU...
# Output shape: torch.Size([2, 4096, 128])
# Total time for 100 runs: 3026.42 ms
# Average time per forward pass: 30.2642 ms
