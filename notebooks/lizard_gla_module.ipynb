# %%
import sys
from pathlib import Path

project_root = Path.cwd().parents[0]
sys.path.append(str(project_root))

# %%
from modules.gla.gla_block import GatedLinearAttention

# %%
import torch

# %%
model = GatedLinearAttention(d_model=1024, num_heads=8, computation_dtype=torch.float32)
model = model.cuda().half()

x = torch.randn(2, 128, 1024, device='cuda', dtype=torch.float16)

print("Warming up GPU...")
for _ in range(10):
    _ = model(x)
torch.cuda.synchronize()

start_event = torch.cuda.Event(enable_timing=True)
end_event = torch.cuda.Event(enable_timing=True)

start_event.record()

n_loops = 100
for _ in range(n_loops):
    y = model(x)

end_event.record()
torch.cuda.synchronize()

elapsed_time_ms = start_event.elapsed_time(end_event)
avg_time = elapsed_time_ms / n_loops

print(f"Output shape: {y.shape}")
print(f"Total time for {n_loops} runs: {elapsed_time_ms:.2f} ms")
print(f"Average time per forward pass: {avg_time:.4f} ms")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 model = GatedLinearAttention(d_model=1024, num_heads=8, computation_dtype=torch.float32)
# ----> 2 model = model.cuda().half()
#       4 x = torch.randn(2, 128, 1024, device='cuda', dtype=torch.float16)
#       6 print("Warming up GPU...")
#
# File ~/tmp/jku-ai-practical-project/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1084, in Module.cuda(self, device)
#    1067 def cuda(self, device: Optional[Union[int, device]] = None) -> Self:
#    1068     r"""Move all model parameters and buffers to the GPU.
#    1069
#    1070     This also makes associated parameters and buffers different objects. So
#    (...)   1082         Module: self
#    1083     """
# -> 1084     return self._apply(lambda t: t.cuda(device))
#
# ...
